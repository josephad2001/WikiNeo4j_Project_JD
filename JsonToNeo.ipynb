# %%
from neo4j import GraphDatabase
import json
import os

# Connect to Neo4j database
uri = "bolt://localhost:7687"
user = "neo4j"
password = "Wikipedia"
driver = GraphDatabase.driver(uri, auth=(user, password))

# Path to the folder containing the JSON files
json_folder = "D:\Wiki\CleanWikiSplit"

# Loop through all the JSON files in the folder
for filename in os.listdir(json_folder):
    if filename.endswith(".json"):
        json_path = os.path.join(json_folder, filename)
        print("Loading File: " + filename)
        # Open the JSON file and load the data
        with open(json_path, encoding='utf-8') as json_file:
            data = json.load(json_file)
            
        # Create a session to execute Neo4j queries
        with driver.session() as session:
            for title, links in data.items():
                session.run("MERGE (b:Article {title: $title})", title=title)
                position = 0
                for link, count in links.items():
                    position = position + 1
                    session.run("MERGE (a:Article {title: $title}) MERGE (b:Article {title: $link_title}) MERGE (a)-[r:LINKS_TO {count: $count, position: $position}]->(b)", title=title, link_title=link, count=count, position=position)
session.close()
driver.close()
# Out:
# Loading File: CleanWikiDump_part000.json
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 30
#      29                     position = position + 1
# ---> 30                     session.run("MERGE (a:Article {title: $title}) MERGE (b:Article {title: $link_title}) MERGE (a)-[r:LINKS_TO {count: $count, position: $position}]->(b)", title=title, link_title=link, count=count, position=position)
#      31 session.close()
#
# File c:\Users\josep\AppData\Local\Programs\Python\Python311\Lib\site-packages\neo4j\_sync\work\session.py:277, in Session.run(self, query, parameters, **kwargs)
#     275 if self._auto_result:
#     276     # This will buffer upp all records for the previous auto-commit tx
# --> 277     self._auto_result._buffer_all()
#     279 if not self._connection:
#
# ...
