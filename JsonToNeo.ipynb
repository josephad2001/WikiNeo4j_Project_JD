# %%
import os
import time
import csv
from neo4j import GraphDatabase

# Connect to the Neo4j database
uri = "bolt://localhost:7687"
user = "neo4j"
password = "12345678"
driver = GraphDatabase.driver(uri, auth=(user, password))

# Path to the folder containing the JSON files
json_folder = "C:\\Users\\josep\\.Neo4jDesktop\\relate-data\dbmss\\dbms-81676b45-399d-492a-b2c6-8199de366b04\\import"

# Create CSV writer for logging node and relationship counts
# Check if the CSV file already exists
csv_file = 'node_count.csv'
if os.path.exists(csv_file):
    # Read the last row from the CSV file and extract the time elapsed value
    with open(csv_file, 'r', newline='') as file:
        reader = csv.reader(file)
        last_row = list(reader)[-1]
        last_time = float(last_row[-1])
    # Start the timer from where it left off
    start_time = time.time() - last_time
else:
    # Create CSV writer for logging node and relationship counts
    with open(csv_file, 'w', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(["FileName", "Nodes", "Relationships", "Time Elapsed"])
    # Start the timer from the beginning
    start_time = time.time()
    file_names = []
    with open(csv_file, 'r') as f:
        reader = csv.reader(f)
        next(reader)  # skip the header row
        for row in reader:
            file_names.append(row[0])

# Get a list of all the JSON files in the folder
json_files = [f for f in os.listdir(json_folder) if f.endswith(".json")]
json_files = sorted(json_files, key=lambda f: os.path.getsize(os.path.join(json_folder, f)))

for filename in json_files:
    if filename in file_names:
        continue
    with driver.session() as session:
        print("Loading File: " + filename)
        out = session.run("""CALL apoc.periodic.iterate(
                    "CALL apoc.load.json('"""+filename+"""') YIELD value
                    WITH value
                    UNWIND keys(value) as article_name
                    RETURN article_name, value[article_name] as related_articles",
                    "MERGE (article:Article {title: article_name})
                    WITH article, related_articles
                    UNWIND keys(related_articles) as related_article_name
                    MERGE (related_article:Article {title: related_article_name})
                    CREATE (article)-[r:LINKS_TO {position: related_articles[related_article_name]}]->(related_article)",
                    {batchSize: 500, parallel: false}
                    )
                    YIELD batches, total
                    RETURN batches, total""")
        #print(out)
        # Get the number of nodes and relationships in the database
        num_nodes = session.run("MATCH (n:Article) RETURN count(n)").single()[0]
        num_rels = session.run("MATCH ()-[r:LINKS_TO]->() RETURN count(r)").single()[0]
        # Log the file name, number of nodes, number of relationships, and current time to the CSV file
        with open('node_count.csv', 'a', newline='') as node_file:
            writer = csv.writer(node_file)
            writer.writerow([filename, num_nodes, num_rels, time.time() - start_time])
    session.close()
# Out:
# Loading File: CleanWikiDump_part451.json
# Loading File: CleanWikiDump_part308.json
# Loading File: CleanWikiDump_part190.json
# Loading File: CleanWikiDump_part431.json
# Loading File: CleanWikiDump_part111.json
# Loading File: CleanWikiDump_part182.json
# Loading File: CleanWikiDump_part181.json
# Loading File: CleanWikiDump_part109.json
# Loading File: CleanWikiDump_part110.json
# Loading File: CleanWikiDump_part367.json
# Loading File: CleanWikiDump_part342.json
# Loading File: CleanWikiDump_part276.json
# Loading File: CleanWikiDump_part449.json
# Loading File: CleanWikiDump_part447.json
# Loading File: CleanWikiDump_part437.json
# Loading File: CleanWikiDump_part189.json
# Loading File: CleanWikiDump_part450.json
# Loading File: CleanWikiDump_part448.json
# Loading File: CleanWikiDump_part364.json
# Loading File: CleanWikiDump_part307.json
# Loading File: CleanWikiDump_part363.json
# Loading File: CleanWikiDump_part343.json
# Loading File: CleanWikiDump_part445.json
# Loading File: CleanWikiDump_part446.json
# Loading File: CleanWikiDump_part432.json
# Loading File: CleanWikiDump_part311.json
# Loading File: CleanWikiDump_part439.json
# Loading File: CleanWikiDump_part444.json
# Loading File: CleanWikiDump_part401.json
# Loading File: CleanWikiDump_part438.json
# Loading File: CleanWikiDump_part150.json
# Loading File: CleanWikiDump_part428.json
# Loading File: CleanWikiDump_part235.json
# Loading File: CleanWikiDump_part443.json
# Loading File: CleanWikiDump_part219.json
# Loading File: CleanWikiDump_part365.json
# Loading File: CleanWikiDump_part433.json
# Loading File: CleanWikiDump_part414.json
# Loading File: CleanWikiDump_part441.json
# Loading File: CleanWikiDump_part315.json
# Loading File: CleanWikiDump_part442.json
# Loading File: CleanWikiDump_part434.json
# Loading File: CleanWikiDump_part389.json
# Loading File: CleanWikiDump_part321.json
# Loading File: CleanWikiDump_part416.json
# Loading File: CleanWikiDump_part188.json
# Loading File: CleanWikiDump_part403.json
# Loading File: CleanWikiDump_part314.json
# Loading File: CleanWikiDump_part309.json
# Loading File: CleanWikiDump_part426.json
# Loading File: CleanWikiDump_part427.json
# Loading File: CleanWikiDump_part435.json
# Loading File: CleanWikiDump_part329.json
# Loading File: CleanWikiDump_part436.json
# Loading File: CleanWikiDump_part340.json
# Loading File: CleanWikiDump_part220.json
# Loading File: CleanWikiDump_part395.json
# Loading File: CleanWikiDump_part429.json
# Loading File: CleanWikiDump_part415.json
# Loading File: CleanWikiDump_part391.json
# Loading File: CleanWikiDump_part440.json
# Loading File: CleanWikiDump_part421.json
# Loading File: CleanWikiDump_part305.json
# Loading File: CleanWikiDump_part378.json
# Loading File: CleanWikiDump_part377.json
# Loading File: CleanWikiDump_part396.json
# Loading File: CleanWikiDump_part128.json
# Loading File: CleanWikiDump_part310.json
# Loading File: CleanWikiDump_part385.json
# Loading File: CleanWikiDump_part366.json
# Loading File: CleanWikiDump_part430.json
# Loading File: CleanWikiDump_part404.json
# Loading File: CleanWikiDump_part394.json
# Loading File: CleanWikiDump_part330.json
# Loading File: CleanWikiDump_part402.json
# Loading File: CleanWikiDump_part390.json
# Loading File: CleanWikiDump_part397.json
# Loading File: CleanWikiDump_part175.json
# Loading File: CleanWikiDump_part337.json
# Loading File: CleanWikiDump_part412.json
# Loading File: CleanWikiDump_part413.json
# Loading File: CleanWikiDump_part410.json
# Loading File: CleanWikiDump_part338.json
# Loading File: CleanWikiDump_part411.json
# Loading File: CleanWikiDump_part384.json
# Loading File: CleanWikiDump_part425.json
# Loading File: CleanWikiDump_part420.json
# Loading File: CleanWikiDump_part393.json
# Loading File: CleanWikiDump_part373.json
# Loading File: CleanWikiDump_part376.json
# Loading File: CleanWikiDump_part419.json
# Loading File: CleanWikiDump_part245.json
# Loading File: CleanWikiDump_part417.json
# Loading File: CleanWikiDump_part405.json
# Loading File: CleanWikiDump_part381.json
# Loading File: CleanWikiDump_part097.json
# Loading File: CleanWikiDump_part244.json
# Loading File: CleanWikiDump_part392.json
# Loading File: CleanWikiDump_part371.json
# Loading File: CleanWikiDump_part350.json
# Loading File: CleanWikiDump_part398.json
# Loading File: CleanWikiDump_part388.json
# Loading File: CleanWikiDump_part372.json
# Loading File: CleanWikiDump_part240.json
# Loading File: CleanWikiDump_part328.json
# Loading File: CleanWikiDump_part370.json
# Loading File: CleanWikiDump_part246.json
# Loading File: CleanWikiDump_part322.json
# Loading File: CleanWikiDump_part358.json
# Loading File: CleanWikiDump_part129.json
# Loading File: CleanWikiDump_part418.json
# Loading File: CleanWikiDump_part326.json
# Loading File: CleanWikiDump_part331.json
# Loading File: CleanWikiDump_part424.json
# Loading File: CleanWikiDump_part325.json
# Loading File: CleanWikiDump_part422.json
# Loading File: CleanWikiDump_part149.json
# Loading File: CleanWikiDump_part191.json
# Loading File: CleanWikiDump_part290.json
# Loading File: CleanWikiDump_part408.json
# Loading File: CleanWikiDump_part303.json
# Loading File: CleanWikiDump_part336.json
# Loading File: CleanWikiDump_part347.json
# Loading File: CleanWikiDump_part339.json
# Loading File: CleanWikiDump_part356.json
# Loading File: CleanWikiDump_part387.json
# Loading File: CleanWikiDump_part344.json
# Loading File: CleanWikiDump_part374.json
# Loading File: CleanWikiDump_part332.json
# Loading File: CleanWikiDump_part333.json
# Loading File: CleanWikiDump_part368.json
# Loading File: CleanWikiDump_part318.json
# Loading File: CleanWikiDump_part348.json
# Loading File: CleanWikiDump_part199.json
# Loading File: CleanWikiDump_part327.json
# Loading File: CleanWikiDump_part375.json
# Loading File: CleanWikiDump_part204.json
# Loading File: CleanWikiDump_part386.json
# Loading File: CleanWikiDump_part218.json
# Loading File: CleanWikiDump_part242.json
# Loading File: CleanWikiDump_part208.json
# Loading File: CleanWikiDump_part112.json
# Loading File: CleanWikiDump_part407.json
# Loading File: CleanWikiDump_part247.json
# Loading File: CleanWikiDump_part172.json
# Loading File: CleanWikiDump_part275.json
# Loading File: CleanWikiDump_part222.json
# Loading File: CleanWikiDump_part353.json
# Loading File: CleanWikiDump_part380.json
# Loading File: CleanWikiDump_part359.json
# Loading File: CleanWikiDump_part345.json
# Loading File: CleanWikiDump_part294.json
# Loading File: CleanWikiDump_part269.json
# Loading File: CleanWikiDump_part423.json
# Loading File: CleanWikiDump_part382.json
# Loading File: CleanWikiDump_part101.json
# Loading File: CleanWikiDump_part287.json
# Loading File: CleanWikiDump_part231.json
# Loading File: CleanWikiDump_part286.json
# Loading File: CleanWikiDump_part383.json
# Loading File: CleanWikiDump_part255.json
# Loading File: CleanWikiDump_part292.json
# Loading File: CleanWikiDump_part400.json
# Loading File: CleanWikiDump_part324.json
# Loading File: CleanWikiDump_part319.json
# Loading File: CleanWikiDump_part300.json
# Loading File: CleanWikiDump_part335.json
# Loading File: CleanWikiDump_part362.json
# Loading File: CleanWikiDump_part369.json
# Loading File: CleanWikiDump_part334.json
# Loading File: CleanWikiDump_part352.json
# Loading File: CleanWikiDump_part346.json
# Loading File: CleanWikiDump_part293.json
# Loading File: CleanWikiDump_part357.json
# Loading File: CleanWikiDump_part237.json
# Loading File: CleanWikiDump_part320.json
# Loading File: CleanWikiDump_part379.json
# Loading File: CleanWikiDump_part243.json
# Loading File: CleanWikiDump_part143.json
# Loading File: CleanWikiDump_part177.json
# Loading File: CleanWikiDump_part291.json
# Loading File: CleanWikiDump_part272.json
# Loading File: CleanWikiDump_part288.json
# Loading File: CleanWikiDump_part409.json
# Loading File: CleanWikiDump_part349.json
# Loading File: CleanWikiDump_part295.json
# Loading File: CleanWikiDump_part236.json
# Loading File: CleanWikiDump_part206.json
# Loading File: CleanWikiDump_part254.json
# Loading File: CleanWikiDump_part360.json
# Loading File: CleanWikiDump_part361.json
# Loading File: CleanWikiDump_part298.json
# Loading File: CleanWikiDump_part241.json
# Loading File: CleanWikiDump_part406.json
# Loading File: CleanWikiDump_part280.json
# Loading File: CleanWikiDump_part351.json
# Loading File: CleanWikiDump_part207.json
# Loading File: CleanWikiDump_part304.json
# Loading File: CleanWikiDump_part234.json
# Loading File: CleanWikiDump_part296.json
# Loading File: CleanWikiDump_part233.json
# Loading File: CleanWikiDump_part228.json
# Loading File: CleanWikiDump_part301.json
# Loading File: CleanWikiDump_part226.json
# Loading File: CleanWikiDump_part297.json
# Loading File: CleanWikiDump_part355.json
# Loading File: CleanWikiDump_part209.json
# Loading File: CleanWikiDump_part256.json
# Loading File: CleanWikiDump_part186.json
# Loading File: CleanWikiDump_part399.json
# Loading File: CleanWikiDump_part266.json
# Loading File: CleanWikiDump_part284.json
# Loading File: CleanWikiDump_part265.json
# Loading File: CleanWikiDump_part271.json
# Loading File: CleanWikiDump_part227.json
# Loading File: CleanWikiDump_part187.json
# Loading File: CleanWikiDump_part211.json
# Loading File: CleanWikiDump_part176.json
# Loading File: CleanWikiDump_part354.json
# Loading File: CleanWikiDump_part215.json
# Loading File: CleanWikiDump_part262.json
# Loading File: CleanWikiDump_part210.json
# Loading File: CleanWikiDump_part313.json
# Loading File: CleanWikiDump_part230.json
# Loading File: CleanWikiDump_part316.json
# Loading File: CleanWikiDump_part193.json
# Loading File: CleanWikiDump_part312.json
# Loading File: CleanWikiDump_part317.json
# Loading File: CleanWikiDump_part263.json
# Loading File: CleanWikiDump_part259.json
# Loading File: CleanWikiDump_part279.json
# Loading File: CleanWikiDump_part217.json
# Loading File: CleanWikiDump_part213.json
# Loading File: CleanWikiDump_part164.json
# Loading File: CleanWikiDump_part270.json
# Loading File: CleanWikiDump_part106.json
# Loading File: CleanWikiDump_part277.json
# Loading File: CleanWikiDump_part299.json
# Loading File: CleanWikiDump_part221.json
# Loading File: CleanWikiDump_part285.json
# Loading File: CleanWikiDump_part323.json
# Loading File: CleanWikiDump_part264.json
# Loading File: CleanWikiDump_part162.json
# Loading File: CleanWikiDump_part214.json
# Loading File: CleanWikiDump_part104.json
# Loading File: CleanWikiDump_part100.json
# Loading File: CleanWikiDump_part302.json
# Loading File: CleanWikiDump_part274.json
# Loading File: CleanWikiDump_part148.json
# Loading File: CleanWikiDump_part108.json
# Loading File: CleanWikiDump_part253.json
# Loading File: CleanWikiDump_part278.json
# Loading File: CleanWikiDump_part281.json
# Loading File: CleanWikiDump_part289.json
# Loading File: CleanWikiDump_part341.json
# Loading File: CleanWikiDump_part238.json
# Loading File: CleanWikiDump_part202.json
# Loading File: CleanWikiDump_part268.json
# Loading File: CleanWikiDump_part203.json
# Loading File: CleanWikiDump_part252.json
# Loading File: CleanWikiDump_part223.json
# Loading File: CleanWikiDump_part282.json
# Loading File: CleanWikiDump_part229.json
# Loading File: CleanWikiDump_part267.json
# Loading File: CleanWikiDump_part153.json
# Loading File: CleanWikiDump_part232.json
# Loading File: CleanWikiDump_part147.json
# Loading File: CleanWikiDump_part216.json
# Loading File: CleanWikiDump_part258.json
# Loading File: CleanWikiDump_part273.json
# Loading File: CleanWikiDump_part180.json
# Loading File: CleanWikiDump_part144.json
# Loading File: CleanWikiDump_part171.json
# Loading File: CleanWikiDump_part306.json
# Loading File: CleanWikiDump_part250.json
# Loading File: CleanWikiDump_part260.json
# Loading File: CleanWikiDump_part251.json
# Loading File: CleanWikiDump_part212.json
# Loading File: CleanWikiDump_part173.json
# Loading File: CleanWikiDump_part196.json
# Loading File: CleanWikiDump_part192.json
# Loading File: CleanWikiDump_part119.json
# Loading File: CleanWikiDump_part183.json
# Loading File: CleanWikiDump_part283.json
# Loading File: CleanWikiDump_part248.json
# Loading File: CleanWikiDump_part103.json
# Loading File: CleanWikiDump_part170.json
# Loading File: CleanWikiDump_part257.json
# Loading File: CleanWikiDump_part134.json
# Loading File: CleanWikiDump_part118.json
# Loading File: CleanWikiDump_part092.json
# Loading File: CleanWikiDump_part194.json
# Loading File: CleanWikiDump_part197.json
# Loading File: CleanWikiDump_part178.json
# Loading File: CleanWikiDump_part163.json
# Loading File: CleanWikiDump_part184.json
# Loading File: CleanWikiDump_part142.json
# Loading File: CleanWikiDump_part093.json
# Loading File: CleanWikiDump_part261.json
# Loading File: CleanWikiDump_part174.json
# Loading File: CleanWikiDump_part160.json
# Loading File: CleanWikiDump_part249.json
# Loading File: CleanWikiDump_part167.json
# Loading File: CleanWikiDump_part151.json
# Loading File: CleanWikiDump_part205.json
# Loading File: CleanWikiDump_part198.json
# Loading File: CleanWikiDump_part239.json
# Loading File: CleanWikiDump_part158.json
# Loading File: CleanWikiDump_part179.json
# Loading File: CleanWikiDump_part169.json
# Loading File: CleanWikiDump_part090.json
# Loading File: CleanWikiDump_part161.json
# Loading File: CleanWikiDump_part201.json
# Loading File: CleanWikiDump_part154.json
# Loading File: CleanWikiDump_part141.json
# Loading File: CleanWikiDump_part157.json
# Loading File: CleanWikiDump_part225.json
# Loading File: CleanWikiDump_part132.json
# Loading File: CleanWikiDump_part131.json
# Loading File: CleanWikiDump_part185.json
# Loading File: CleanWikiDump_part224.json
# Loading File: CleanWikiDump_part120.json
# Loading File: CleanWikiDump_part139.json
# Loading File: CleanWikiDump_part156.json
# Loading File: CleanWikiDump_part145.json
# Loading File: CleanWikiDump_part130.json
# Loading File: CleanWikiDump_part127.json
# Loading File: CleanWikiDump_part116.json
# Loading File: CleanWikiDump_part081.json
# Loading File: CleanWikiDump_part114.json
# Loading File: CleanWikiDump_part166.json
# Loading File: CleanWikiDump_part099.json
# Loading File: CleanWikiDump_part155.json
# Loading File: CleanWikiDump_part200.json
# Loading File: CleanWikiDump_part113.json
# Loading File: CleanWikiDump_part105.json
# Loading File: CleanWikiDump_part123.json
# Loading File: CleanWikiDump_part133.json
# Loading File: CleanWikiDump_part121.json
# Loading File: CleanWikiDump_part138.json
# Loading File: CleanWikiDump_part095.json
# Loading File: CleanWikiDump_part091.json
# Loading File: CleanWikiDump_part137.json
# Loading File: CleanWikiDump_part117.json
# Loading File: CleanWikiDump_part165.json
# Loading File: CleanWikiDump_part146.json
# Loading File: CleanWikiDump_part152.json
# Loading File: CleanWikiDump_part107.json
# Loading File: CleanWikiDump_part125.json
# Loading File: CleanWikiDump_part136.json
# Loading File: CleanWikiDump_part102.json
# Loading File: CleanWikiDump_part115.json
# Loading File: CleanWikiDump_part096.json
# Loading File: CleanWikiDump_part122.json
# Loading File: CleanWikiDump_part086.json
# Loading File: CleanWikiDump_part168.json
# Loading File: CleanWikiDump_part058.json
# Loading File: CleanWikiDump_part126.json
# Loading File: CleanWikiDump_part140.json
# Loading File: CleanWikiDump_part094.json
# Loading File: CleanWikiDump_part135.json
# Loading File: CleanWikiDump_part124.json
# Loading File: CleanWikiDump_part195.json
# Loading File: CleanWikiDump_part083.json
# Loading File: CleanWikiDump_part085.json
# Loading File: CleanWikiDump_part089.json
# Loading File: CleanWikiDump_part082.json
# Loading File: CleanWikiDump_part088.json
# Loading File: CleanWikiDump_part084.json
# Loading File: CleanWikiDump_part098.json
# Loading File: CleanWikiDump_part074.json
# Loading File: CleanWikiDump_part075.json
# Loading File: CleanWikiDump_part065.json
# Loading File: CleanWikiDump_part078.json
# Loading File: CleanWikiDump_part068.json
# Loading File: CleanWikiDump_part159.json
# Loading File: CleanWikiDump_part063.json
# Loading File: CleanWikiDump_part064.json
# Loading File: CleanWikiDump_part080.json
# Loading File: CleanWikiDump_part071.json
# Loading File: CleanWikiDump_part087.json
# Loading File: CleanWikiDump_part072.json
# Loading File: CleanWikiDump_part070.json
# Loading File: CleanWikiDump_part066.json
# Loading File: CleanWikiDump_part076.json
# Loading File: CleanWikiDump_part073.json
# Loading File: CleanWikiDump_part062.json
# Loading File: CleanWikiDump_part067.json
# Loading File: CleanWikiDump_part059.json
# Loading File: CleanWikiDump_part069.json
# Loading File: CleanWikiDump_part054.json
# Loading File: CleanWikiDump_part079.json
# Loading File: CleanWikiDump_part060.json
# Loading File: CleanWikiDump_part028.json
# Loading File: CleanWikiDump_part053.json
# Loading File: CleanWikiDump_part057.json
# Loading File: CleanWikiDump_part047.json
# Loading File: CleanWikiDump_part052.json
# Loading File: CleanWikiDump_part056.json
# Loading File: CleanWikiDump_part061.json
# Loading File: CleanWikiDump_part046.json
# Loading File: CleanWikiDump_part055.json
# Loading File: CleanWikiDump_part048.json
# Loading File: CleanWikiDump_part044.json
# Loading File: CleanWikiDump_part043.json
# Loading File: CleanWikiDump_part077.json
# Loading File: CleanWikiDump_part051.json
# Loading File: CleanWikiDump_part050.json
# Loading File: CleanWikiDump_part009.json
# Loading File: CleanWikiDump_part045.json
# Loading File: CleanWikiDump_part049.json
# Loading File: CleanWikiDump_part042.json
# Loading File: CleanWikiDump_part041.json
# Loading File: CleanWikiDump_part037.json
# Loading File: CleanWikiDump_part036.json
# Loading File: CleanWikiDump_part034.json
# Loading File: CleanWikiDump_part038.json
# Loading File: CleanWikiDump_part040.json
# Loading File: CleanWikiDump_part039.json
# Loading File: CleanWikiDump_part033.json
# Loading File: CleanWikiDump_part035.json
# Loading File: CleanWikiDump_part031.json
# Loading File: CleanWikiDump_part030.json
# Loading File: CleanWikiDump_part027.json
# Loading File: CleanWikiDump_part032.json
# Loading File: CleanWikiDump_part029.json
# Loading File: CleanWikiDump_part026.json
# Loading File: CleanWikiDump_part025.json
# Loading File: CleanWikiDump_part022.json
# Loading File: CleanWikiDump_part021.json
# Loading File: CleanWikiDump_part024.json
# Loading File: CleanWikiDump_part023.json
# Loading File: CleanWikiDump_part018.json
# Loading File: CleanWikiDump_part019.json
# Loading File: CleanWikiDump_part020.json
# Loading File: CleanWikiDump_part015.json
# Loading File: CleanWikiDump_part016.json
# Loading File: CleanWikiDump_part017.json
# Loading File: CleanWikiDump_part014.json
# Loading File: CleanWikiDump_part012.json
# Loading File: CleanWikiDump_part013.json
# Loading File: CleanWikiDump_part011.json
# Loading File: CleanWikiDump_part010.json
# Loading File: CleanWikiDump_part008.json
# Loading File: CleanWikiDump_part006.json
# Loading File: CleanWikiDump_part007.json
# Loading File: CleanWikiDump_part005.json
# Loading File: CleanWikiDump_part004.json
# Loading File: CleanWikiDump_part003.json
# Loading File: CleanWikiDump_part001.json
# Loading File: CleanWikiDump_part002.json
# Loading File: CleanWikiDump_part000.json

# %%
import os
import json
import time
import csv
from neo4j import GraphDatabase
from threading import Thread

# Connect to Neo4j database
uri = "bolt://localhost:7687"
user = "neo4j"
password = "Wikipedia"
driver = GraphDatabase.driver(uri, auth=(user, password))

# Path to the folder containing the JSON files
json_folder = "D:\Wiki\CleanWikiSplit"

# Create CSV writer for logging node and relationship counts
with open('node_count.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Batch Number", "Nodes", "Relationships", "Time Elapsed"])

# Number of files to process in each batch
batch_size = 10

# Get a list of all the JSON files in the folder
json_files = [f for f in os.listdir(json_folder) if f.endswith(".json")]

# Split the list of files into batches
file_batches = [json_files[i:i + batch_size] for i in range(0, len(json_files), batch_size)]

# Create a function to process a batch of files
def process_batch(batch):
    # Create a session to execute Neo4j queries
    with driver.session() as session:
        # Loop through all the files in the batch
        for filename in batch:
            json_path = os.path.join(json_folder, filename)
            print("Loading File: " + filename)

            # Open the JSON file and load the data
            with open(json_path, encoding='utf-8') as json_file:
                data = json.load(json_file)

            # Loop through all the articles in the JSON data
            for title, links in data.items():
                session.run("CREATE (b:Article {title: $title})", title=title.lower())
                position = 0
                for link, count in links.items():
                    position += 1
                    session.run("CREATE (b:Article {title: $title})", title=link.lower())
                    session.run("""
                    MATCH (a:Article {title: $title}) MATCH (b:Article {title: $link_title}) 
                    CREATE (a)-[r:LINKS_TO {count: $count, position: $position}]->(b)"""
                                , title=title.lower(), link_title=link.lower(), count=count, position=position)
    session.close()

# Start the timer
start_time = time.time()

# Loop through all the batches of files
batchcount = 0
for batch in file_batches:
    batchcount = batchcount + 1
    # Create a list of threads to process the batch
    threads = []
    for filename in batch:
        thread = Thread(target=process_batch, args=([filename],))
        threads.append(thread)

    # Start the threads
    for thread in threads:
        thread.start()

    # Wait for all the threads to finish
    for thread in threads:
        thread.join()

    with driver.session() as session:
        # Get the number of nodes and relationships in the database
        num_nodes = session.run("MATCH (n:Article) RETURN count(n)").single()[0]
        num_rels = session.run("MATCH ()-[r:LINKS_TO]->() RETURN count(r)").single()[0]

        # Log the file name, number of nodes, number of relationships, and current time to the CSV file
        with open('node_count.csv', 'a', newline='') as node_file:
                writer = csv.writer(node_file)
                writer.writerow([batchcount, num_nodes, num_rels, time.time() - start_time])
    session.close()

# Close the Neo4j driver
driver.close()
# Out:
# Loading File: CleanWikiDump_part000.json
# Loading File: CleanWikiDump_part001.json
# Loading File: CleanWikiDump_part002.json
# Loading File: CleanWikiDump_part003.json
# Loading File: CleanWikiDump_part004.json
# Loading File: CleanWikiDump_part005.json
# Loading File: CleanWikiDump_part006.json
# Loading File: CleanWikiDump_part007.json
# Loading File: CleanWikiDump_part008.json
# Loading File: CleanWikiDump_part009.json
# Loading File: CleanWikiDump_part010.json
# Loading File: CleanWikiDump_part011.json
# Loading File: CleanWikiDump_part012.json
# Loading File: CleanWikiDump_part013.json
# Loading File: CleanWikiDump_part014.json
